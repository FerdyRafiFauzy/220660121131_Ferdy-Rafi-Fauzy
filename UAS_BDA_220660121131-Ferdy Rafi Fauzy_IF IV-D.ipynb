# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Data transaksi
data = {
    'Sneakers': [0, 1, 1, 0, 1],
    'Running Shoes': [1, 0, 1, 1, 0],
    'Slip on': [1, 1, 1, 0, 0],
    'Boots': [0, 0, 1, 1, 1],
    'loafers': [0, 1, 1, 1, 0]
}

df = pd.DataFrame(data)

# Menghasilkan frequent itemsets
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

# Menghasilkan aturan asosiasi
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# Menampilkan hasil
print(frequent_itemsets)
print(rules)
# Out:
#     support                         itemsets
# 0       0.6                       (Sneakers)
# 1       0.6                  (Running Shoes)
# 2       0.6                        (Slip on)
# 3       0.6                          (Boots)
# 4       0.6                        (loafers)
# 5       0.4              (Slip on, Sneakers)
# 6       0.4                (Boots, Sneakers)
# 7       0.4              (loafers, Sneakers)
# 8       0.4         (Slip on, Running Shoes)
# 9       0.4           (Boots, Running Shoes)
# 10      0.4         (loafers, Running Shoes)
# 11      0.4               (loafers, Slip on)
# 12      0.4                 (Boots, loafers)
# 13      0.4     (loafers, Slip on, Sneakers)
# 14      0.4  (Boots, loafers, Running Shoes)
#                  antecedents               consequents  antecedent support  \
# 0                  (Slip on)                (Sneakers)                 0.6
# 1                 (Sneakers)                 (Slip on)                 0.6
# 2                    (Boots)                (Sneakers)                 0.6
# 3                 (Sneakers)                   (Boots)                 0.6
# 4                  (loafers)                (Sneakers)                 0.6
# 5                 (Sneakers)                 (loafers)                 0.6
# 6                  (Slip on)           (Running Shoes)                 0.6
# 7            (Running Shoes)                 (Slip on)                 0.6
# 8                    (Boots)           (Running Shoes)                 0.6
# 9            (Running Shoes)                   (Boots)                 0.6
# 10                 (loafers)           (Running Shoes)                 0.6
# 11           (Running Shoes)                 (loafers)                 0.6
# 12                 (loafers)                 (Slip on)                 0.6
# 13                 (Slip on)                 (loafers)                 0.6
# 14                   (Boots)                 (loafers)                 0.6
# 15                 (loafers)                   (Boots)                 0.6
# 16        (loafers, Slip on)                (Sneakers)                 0.4
# 17       (loafers, Sneakers)                 (Slip on)                 0.4
# 18       (Slip on, Sneakers)                 (loafers)                 0.4
# 19                 (loafers)       (Slip on, Sneakers)                 0.6
# 20                 (Slip on)       (loafers, Sneakers)                 0.6
# 21                (Sneakers)        (loafers, Slip on)                 0.6
# 22          (Boots, loafers)           (Running Shoes)                 0.4
# 23    (Boots, Running Shoes)                 (loafers)                 0.4
# 24  (loafers, Running Shoes)                   (Boots)                 0.4
# 25                   (Boots)  (loafers, Running Shoes)                 0.6
# 26                 (loafers)    (Boots, Running Shoes)                 0.6
# 27           (Running Shoes)          (Boots, loafers)                 0.6
#
#     consequent support  support  confidence      lift  leverage  conviction  \
# 0                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 1                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 2                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 3                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 4                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 5                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 6                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 7                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 8                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 9                  0.6      0.4    0.666667  1.111111      0.04         1.2
# 10                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 11                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 12                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 13                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 14                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 15                 0.6      0.4    0.666667  1.111111      0.04         1.2
# 16                 0.6      0.4    1.000000  1.666667      0.16         inf
# 17                 0.6      0.4    1.000000  1.666667      0.16         inf
# 18                 0.6      0.4    1.000000  1.666667      0.16         inf
# 19                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 20                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 21                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 22                 0.6      0.4    1.000000  1.666667      0.16         inf
# 23                 0.6      0.4    1.000000  1.666667      0.16         inf
# 24                 0.6      0.4    1.000000  1.666667      0.16         inf
# 25                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 26                 0.4      0.4    0.666667  1.666667      0.16         1.8
# 27                 0.4      0.4    0.666667  1.666667      0.16         1.8
#
#     zhangs_metric
# 0        0.250000
# 1        0.250000
# 2        0.250000
# 3        0.250000
# 4        0.250000
# 5        0.250000
# 6        0.250000
# 7        0.250000
# 8        0.250000
# 9        0.250000
# 10       0.250000
# 11       0.250000
# 12       0.250000
# 13       0.250000
# 14       0.250000
# 15       0.250000
# 16       0.666667
# 17       0.666667
# 18       0.666667
# 19       1.000000
# 20       1.000000
# 21       1.000000
# 22       0.666667
# 23       0.666667
# 24       0.666667
# 25       1.000000
# 26       1.000000
# 27       1.000000
# C:\Users\Lenovo\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
